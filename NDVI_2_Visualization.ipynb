# %%
# !pip install earthengine-api
# !pip install geehydro
# !pip install geemap
# !pip install geetools
# !pip install jupyter_contrib_nbextensions
# !pip install ndvi2gif

# %%
import ee
import folium
import geehydro
import geemap
import geetools
import os

# %%
# ee.Authenticate()
ee.Initialize()

# %%
d = ee.ImageCollection('NOAA/PERSIANN-CDR').select('precipitation')
d = d.first().propertyNames()
print(d.getInfo())
# Out:
# ['system:time_start', 'month', 'system:footprint', 'system:time_end', 'system:version', 'system:id', 'system:asset_size', 'system:index', 'system:bands', 'system:band_names']

# %%
Map = geemap.Map()
Map
# Out:
# Map(center=[40, -100], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(T…

# %%
landsat7 = ee.Image('LE7_TOA_5YEAR/1999_2003') \
    .select([0, 1, 2, 3, 4, 6])
landsat_vis = {
    'bands': ['B4', 'B3', 'B2'], 
    'gamma': 1.4
}
Map.addLayer(landsat7, landsat_vis, "LE7_TOA_5YEAR/1999_2003")

hyperion = ee.ImageCollection('EO1/HYPERION') \
    .filter(ee.Filter.date('2016-01-01', '2017-03-01'));
hyperion_vis = {
  'min': 1000.0,
  'max': 14000.0,
  'gamma': 2.5,
}
Map.addLayer(hyperion, hyperion_vis, 'EO1/HYPERION');

# %%
m = geemap.Map()
m.add_basemap('Google Satellite')
m
# Out:
# Map(center=[40, -100], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(T…

# %%
soums = ee.FeatureCollection('users/ta346/soum')

# %%
m.addLayer(soums, {}, 'soum')

# %%
from ndvi2gif import NdviSeasonality
myclass2 = NdviSeasonality(soums, 1985, 2020, 'Landsat', 'median')
median = myclass2.get_year_composite().median()
vizParams = {'bands': ['summer', 'autumn', 'winter'], 'min': 0, 'max': 0.7, 'gamma': [0.95, 1.1, 1]}
m.addLayer(median, vizParams, 'soum')

# %%
myclass2.get_gif()
# Out:
# Generating URL...
# Downloading GIF image from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/videoThumbnails/31aa5151cfed79151a0ba64d041e22e2-8fd25c658e0ca8366e3eb38c56493fe3:getPixels
# Please wait ...
# The GIF image has been saved to: U:\honors thesis\gee_python\mygif.gif

# %% [markdown]
# # EE TimeSeries and TimeLapse
#
# ## Main functions
#
# naip_timeseries(roi=None, start_year=2009, end_year=2018):
#
# landsat_timeseries() #return collection from landsat
#
# landsat_ts_gif() #Generates a Landsat timelapse GIF image.
#
# add_text_to_gid() #Adds animated text to a GIF image.
#
# add_image_to_gif() #Adds an image logo to a GIF image.
#
# reduce_gif_size() #Reduces a GIF image using ffmpeg.
#
# landsat_ts_norm_diff() #Computes a normalized difference index based on a Landsat timeseries.
#
# landsat_ts_norm_diff_gif() #summary - uses landsat_ts_norm_diff()
#
# Map.add_landsat_ts_gif() #add gif to the map and download the gif

# %%
Map = geemap.Map()
Map
# Out:
# Map(center=[40, -100], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(T…

# %%
roi = ee.Geometry.Polygon(
    [[[-115.471773, 35.892718],
      [-115.471773, 36.409454],
        [-114.271283, 36.409454],
        [-114.271283, 35.892718],
        [-115.471773, 35.892718]]], None, False)

# %%
collection = geemap.landsat_timeseries(roi=roi, start_year=1985, end_year=2019, start_date='06-10', end_date='09-20')

# %%
Map2 = geemap.Map()
Map2
# Out:
# Map(center=[40, -100], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(T…

# %%
first_image = collection.first()

vis = {
    'bands': ['NIR', 'Red', 'Green'],
    'min': 0,
    'max': 4000,
    'gamma': [1, 1, 1]
}

Map2.addLayer(first_image, vis, 'First image')

# %%
roi = Map.draw_last_feature
roi = roi.geometry()

# %%
colorizedVis = {
  'min': 0.0,
  'max': 1.0,
  'palette': [
    'FFFFFF', 'CE7E45', 'DF923D', 'F1B555', 'FCD163', '99B718', '74A901',
    '66A000', '529400', '3E8601', '207401', '056201', '004C00', '023B01',
    '012E01', '011D01', '011301'
  ],
}

# %%
Map.add_landsat_ts_gif(layer_name='TimeLapse',
                       roi=roi,
                       start_year=1985, 
                       end_year=2020, 
                       start_date='06-01', 
                       end_date='08-31', 
                       dimensions=768, 
                       frames_per_second=5, 
                       nd_bands=['NIR', 'Red'], 
                       nd_palette=colorizedVis)
# Out:
# Generating URL...
# Downloading GIF image from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/videoThumbnails/69c9c3b462f9a33c7962b5c9b210be21-0f458a62e92151c4e72a12d911850c94:getPixels
# Please wait ...
# An error occurred while downloading.
# Generating URL...
# Error in map(ID=2):
# Image.visualize: Expected a string or list of strings for field 'palette'.
# Adding animated text to GIF ...
# The input gif file does not exist.
# The input gif file does not exist.
# The input gif file does not exist.
# The input gif file does not exist.
# Adding GIF to the map ...
# The provided file does not exist.
# The provided file does not exist.
# The timelapse has been added to the map.

# %%
#mask cloud, snow, shadow ...for landsat 5-8
#Documentation: https://github.com/gee-community/gee_tools/blob/master/geetools/cloud_mask.py 
from geetools import cloud_mask
mask_LS_SR = cloud_mask.landsatSR()

# %%
#ndvi function for image collections for landsat 8
def ndviFun_ls8(im):
  ndvi = im.normalizedDifference(['B5','B4']).rename('ndvi').copyProperties(im, ['system:time_start'])
  return im.addBands(ndvi)

#ndvi function for landsat 5 and 7 image collections
def ndviFun_ls57(im):
  ndvi = im.normalizedDifference(['B4','B3']).rename('ndvi').copyProperties(im, ['system:time_start'])
  return im.addBands(ndvi)

#Sensor calibaration functions

#landsat 8 to 7 using coefficient found in D.P.Roy et el (2016)
def applyCoefficientL7(image):
  image_adjusted = image.select('ndvi').toFloat().copyProperties(image, ['system:time_start'])
  return(image_adjusted)

def applyCoefficientL8(image):
  image_adjusted = image.select('ndvi').multiply(0.9589).toFloat().copyProperties(image, ['system:time_start'])
  return(image_adjusted)

#landsat 5 to landsat 7 using coefficient found in Junchang and Masek (2017)
def applyCoefficientL5(image):
  image_adjusted = image.select('ndvi').multiply(1.037).toFloat().copyProperties(image, ['system:time_start'])
  return(image_adjusted)

# %%
# Read soum shapefiles from GEE assets
soums = ee.FeatureCollection('users/ta346/soum')
Map.addLayer(soums, {}, 'Soums')
Map.centerObject(soums)

# %%
#2020 LANDCOVER 30m
# //Source: http://www.globallandcover.com/defaults_en.html?src=/Scripts/map/defaults/En/download_en.html&head=download&type=data
# //name: 2020 global landcover 30m
# //downloaded locally and imported as an asset

# //Classification codes: Cultivated Land：10；Forest：20；Grass Land：30；Shrubland：40；Wetland：50；Water Body：60；Tundra：70；Artificial Surfaces：80；Bareland：90；Permanent Snow and Ice：100
# //mask: wetland 50, waterbody 60, Artificial surfaces 80, Permenant snow and ice 100
landcover = ee.Image('users/ta346/2020LC30')
lc = landcover.clip(soums).select('b1')

#to make landcover mask and display - masked areas are black (i.e zero)
mask_lc = lc.neq(50).And(lc.neq(60)).And(lc.neq(80)).And(lc.neq(100))
Map.addLayer(mask_lc, {}, 'landcover (30m)') #Looks Ok!

#function to map over the ndvi dataset collection
def maskLandCover (img):
    return img.updateMask(mask_lc).copyProperties(img, ['system:time_start'])

# %%
out_dir = r'U:\honors thesis\gee_python\downloads\gif'
out_gif = os.path.join(out_dir, "landsat_ts_2985_2019.gif")

# %%
# create collection images of landsat 5, 7, and 8; calibrated, filtered for 6, 7, 8 months.
l8 = ee.ImageCollection('LANDSAT/LC08/C01/T1_SR') \
    .filterBounds(soums) \
    .filter(ee.Filter.dayOfYear(120, 240)) \
    .filterDate('2013-05-01', '2020-08-31') \
    .map(mask_LS_SR) \
    .map(maskLandCover) \
    .map(ndviFun_ls8) \
    .map(applyCoefficientL8)
l7 = ee.ImageCollection('LANDSAT/LE07/C01/T1_SR') \
    .filterBounds(soums) \
    .filter(ee.Filter.dayOfYear(120, 240)) \
    .filterDate('1999-05-01', '2020-08-31') \
    .map(mask_LS_SR)  \
    .map(maskLandCover) \
    .map(ndviFun_ls57) \
    .map(applyCoefficientL7) 
l5 = ee.ImageCollection('LANDSAT/LT05/C01/T1_SR') \
    .filterBounds(soums) \
    .filter(ee.Filter.dayOfYear(120, 240)) \
    .filterDate('1984-05-01', '2011-08-31') \
    .map(mask_LS_SR) \
    .map(maskLandCover) \
    .map(ndviFun_ls57) \
    .map(applyCoefficientL5)

# merge all the collections
mc = ee.ImageCollection(l8.merge(l7.merge(l5))).select('ndvi')

# %%
#Download ndvi the collection by distinct date and each soum - newcol 
#first, set the dates
start = ee.Date('2020-05-01')
finish = ee.Date('2020-08-31')

# Difference in days between start and finish
diff = finish.difference(start, 'day')
print(diff.getInfo())

temporalResolution = 7  # days - can be adjusted so that collect image collection by 8 days, 16 days, etc

# Make a list of all dates
def function(day):
    return start.advance(day,'day')

# date range
range_dates = ee.List.sequence(0, diff.subtract(1), temporalResolution).map(function)
print(range_dates.size().getInfo())

# for each distinct date in temoralresoultion, mosaic and return as a list of images
def day_mosaics(date, newlist):
  # Cast
  date = ee.Date(date)
  newlist = ee.List(newlist)

  # Filter collection between date and the next day
  filtered = mc.filterDate(date, date.advance(temporalResolution, 'day'))

  # Make the mosaic
  image = ee.Image(filtered.reduce(ee.Reducer.mean()).clip(soums)) \
                    .set("system:index", date.format("YYYMMdd")) 

  # Add the mosaic to a list only if the collection has images
  return ee.List(ee.Algorithms.If(filtered.size(), newlist.add(image), newlist))

#Create image collection from the list of images
newcol = ee.ImageCollection(ee.List(range_dates.iterate(day_mosaics, ee.List([]))))
print(newcol.size().getInfo())
# Out:
# 122
# 18
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# ~\.conda\envs\gee\lib\site-packages\ee\data.py in _execute_cloud_call(call, num_retries)
#     333   try:
# --> 334     return call.execute(num_retries=num_retries)
#     335   except googleapiclient.errors.HttpError as e:
#
# ~\.conda\envs\gee\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#
# ~\.conda\envs\gee\lib\site-packages\googleapiclient\http.py in execute(self, http, num_retries)
#     914         if resp.status >= 300:
# --> 915             raise HttpError(resp, content, uri=self.uri)
#     916         return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/value:compute?prettyPrint=false&alt=json returned "User memory limit exceeded.". Details: "User memory limit exceeded.">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# <ipython-input-136-8dfc56101010> in <module>
#      36 #Create image collection from the list of images
#      37 newcol = ee.ImageCollection(ee.List(range_dates.iterate(day_mosaics, ee.List([]))))
# ---> 38 print(newcol.size().getInfo())
#
# ~\.conda\envs\gee\lib\site-packages\ee\computedobject.py in getInfo(self)
#      93       The object can evaluate to anything.
#      94     """
# ---> 95     return data.computeValue(self)
#      96
#      97   def encode(self, encoder):
#
# ~\.conda\envs\gee\lib\site-packages\ee\data.py in computeValue(obj)
#     672     The result of evaluating that object on the server.
#     673   """
# --> 674   return _execute_cloud_call(
#     675       _get_cloud_api_resource().projects().value().compute(
#     676           body={'expression': serializer.encode(obj, for_cloud_api=True)},
#
# ~\.conda\envs\gee\lib\site-packages\ee\data.py in _execute_cloud_call(call, num_retries)
#     334     return call.execute(num_retries=num_retries)
#     335   except googleapiclient.errors.HttpError as e:
# --> 336     raise _translate_cloud_exception(e)
#     337
#     338
#
# EEException: User memory limit exceeded.

# %%
m2 = geemap.Map()
m2.addLayer(yearlyNDVI, colorizedVis, 'Summer Median')
m2
# Out:
# Map(center=[40, -100], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(T…
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# DYCI3PX6II6V3I6LBVIBFPSS  Export.table  daily_ndvi_by_soum_2000                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# DMLZZGQ2ZUWMKVZXLVXSMHQO  Export.table  daily_ndvi_by_soum_2000                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# 2XF575VC5EUZFCWZ6E6LQYM2  Export.table  daily_ndvi_by_soum_2014                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-0.9589, 0.9589>.
#   Actual type: Float<-1.0, 1.0>.
#      Image ID: LE07_131031_20140531
# This band might require an explicit cast.
# I6F7WDJJTHW3DC6CJSZKCI2H  Export.table  daily_ndvi_by_soum_2020                     CANCELLED  Cancelled.
# VMZ3COONST2JPMVWZAA7KZW3  Export.table  daily_ndvi_by_soum_2020                     CANCELLED  Cancelled.
# EIUZ3OJQSJCVY6QS4O3XCCEC  Export.table  daily_ndvi_by_soum_2020                     CANCELLED  Cancelled.
# UH6JIO4RBBODJHGINBOMIZQF  Export.table  daily_ndvi_by_soum_2020                     CANCELLED  Cancelled.
# 47ZPBRNFFN57NVJRAX33EPLP  Export.table  daily_ndvi_by_soum_2019                     CANCELLED  Cancelled.
# W47GU5HRSLIV2ZH3UC2Z73B7  Export.table  daily_ndvi_by_soum_2018                     CANCELLED  Cancelled.
# QFNSROLJBY2C4OUDC4Y4JP2Z  Export.table  daily_ndvi_by_soum_2017                     CANCELLED  Cancelled.
# RZBWUOY5CVVEHS4P6WI5UIKB  Export.table  daily_ndvi_by_soum_2016                     CANCELLED  Cancelled.
# RH5E53KKQBXATS2UKUB6PBB3  Export.table  daily_ndvi_by_soum_2015                     CANCELLED  Cancelled.
# WSNWMAL5KDW6IV2VBPJSDGOW  Export.table  daily_ndvi_by_soum_2014                     CANCELLED  Cancelled.
# 5AOVKLPR5KYJEIU6QQNQNBH4  Export.table  daily_ndvi_by_soum_2013                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-0.9589, 0.9589>.
#   Actual type: Float<-1.0, 1.0>.
#      Image ID: LE07_123027_20130504
# This band might require an explicit cast.
# 3LFEHMBASK7OKT5XC5NBFSOX  Export.table  daily_ndvi_by_soum_2012                     CANCELLED  Cancelled.
# 3A26ZK6S4II7PZLRQR5CLUQN  Export.table  daily_ndvi_by_soum_2011                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# 4VRWB7C7TV7I77ZG5OZLYMAM  Export.table  daily_ndvi_by_soum_2010                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# R2LZDJE34KOALJ624WGIBONA  Export.table  daily_ndvi_by_soum_2009                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# I5IOR3BLCWTVLIO4F6WCL6FP  Export.table  daily_ndvi_by_soum_2008                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# XQ2MZPVZDXHWP6ORHJGO4HY2  Export.table  daily_ndvi_by_soum_2007                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# BDJWO6K6LGB7XBRS5ESQVUYL  Export.table  daily_ndvi_by_soum_2006                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# BKVQK6Z5UOK756QKK2HRAT7R  Export.table  daily_ndvi_by_soum_2005                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# QWZBXN5C3FB7PQBFNWD7XKXD  Export.table  daily_ndvi_by_soum_2004                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# IRT27FY27NYTLL2H7NSKWBFA  Export.table  daily_ndvi_by_soum_2003                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# ZUEB2GRV57MQYQ5I6FS3XGAZ  Export.table  daily_ndvi_by_soum_2002                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# YHQ2BLQSZTO2ZFUQUTZWROFE  Export.table  daily_ndvi_by_soum_2001                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# H5IKRIV3ZPHK6OG34FMS62UB  Export.table  daily_ndvi_by_soum_2000                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# 64VVDBYEAS3GCF3PFQDXSGAC  Export.table  daily_ndvi_by_soum_1999                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# T36QRKKBCLJTMQ3AS24XEX62  Export.table  daily_ndvi_by_soum_1998                     COMPLETED  ---
# FWIL5ANEXRXI4JQXCAH76NAH  Export.table  daily_ndvi_by_soum_1997                     COMPLETED  ---
# D3CQHOBBC2RWAZOOALNFWVDF  Export.table  daily_ndvi_by_soum_1996                     COMPLETED  ---
# H5FLY4JWZCQ4TEELQQNSJZOM  Export.table  daily_ndvi_by_soum_1995                     COMPLETED  ---
# JUPFD6EJDPINXBG7TUTHS2H6  Export.table  daily_ndvi_by_soum_1994                     COMPLETED  ---
# SRLZVLBRYRD7OVMNVBP6ER7E  Export.table  daily_ndvi_by_soum_1993                     COMPLETED  ---
# N3URBPDMQ46QKXZLRX3FLRQL  Export.table  daily_ndvi_by_soum_1992                     COMPLETED  ---
# J7MPVFXQKV4AYI3OSYUYXC6G  Export.table  daily_ndvi_by_soum_1991                     COMPLETED  ---
# 2JUB22FDRNKUIYMAAZVDJIFU  Export.table  daily_ndvi_by_soum_1990                     COMPLETED  ---
# GAPCAKMQNWLSBXXF34NM46B5  Export.table  daily_ndvi_by_soum_1989                     COMPLETED  ---
# 2WXSRHR3XTREK5NV4TKOGZ7M  Export.table  daily_ndvi_by_soum_1988                     COMPLETED  ---
# UPZZ6EQK2Q2GETO5QUD7IBI3  Export.table  daily_ndvi_by_soum_1987                     COMPLETED  ---
# J73LX75Y4UXVNHMVDXSXGGNP  Export.table  daily_ndvi_by_soum_1986                     COMPLETED  ---
# 6DPMMUFJ7JJNAESZZWLI6GCA  Export.table  daily_ndvi_by_soum_1985                     COMPLETED  ---
# 6MSVO3WHB6YMPJO3W6F7HDZA  Export.table  daily_ndvi_by_soum_1985                     CANCELLED  Cancelled.
# MU7I4RZ3D4HDPUPTUIC4YV2M  Export.table  daily_ndvi_by_soum_1985                     CANCELLED  Cancelled.
# RYVXX7MVAC45UZJ7ABXYDIXK  Export.table  daily_ndvi_by_soum_2020                     CANCELLED  Cancelled.
# QW5MKFAAYEIILB2DJJHRJHAO  Export.table  daily_ndvi_by_soum_2019                     CANCELLED  Cancelled.
# X6UE2VGQYRCYESHY7PHNIIML  Export.table  daily_ndvi_by_soum_2018                     CANCELLED  Cancelled.
# WFXBKF2YN3CBZD4V3T4FMETV  Export.table  daily_ndvi_by_soum_2017                     CANCELLED  Cancelled.
# 6KQSM273Q3QTTYEEUHEIZQIM  Export.table  daily_ndvi_by_soum_2016                     CANCELLED  Cancelled.
# GL7HKITRM2G2HYXVAP6MYHEK  Export.table  daily_ndvi_by_soum_2015                     CANCELLED  Cancelled.
# AZBOMXKKGR27JVVQWPU6MXQC  Export.table  daily_ndvi_by_soum_2014                     CANCELLED  Cancelled.
# RRSHR6WEYTNNOXUA5F3GEEOJ  Export.table  daily_ndvi_by_soum_2013                     CANCELLED  Cancelled.
# ZSEXSFHSDCMF3OHK4KGDTMC3  Export.table  daily_ndvi_by_soum_2012                     CANCELLED  Cancelled.
# PYNE62OIODYJE5KUMSEBYU7R  Export.table  daily_ndvi_by_soum_2011                     CANCELLED  Cancelled.
# ASNISL23TG3R5XG57V2SWYC3  Export.table  daily_ndvi_by_soum_2010                     CANCELLED  Cancelled.
# O5U7WDT5HDVL6SGGTMRQV2IH  Export.table  daily_ndvi_by_soum_2009                     CANCELLED  Cancelled.
# IO7IVUMUJNFV5JOIQ5UJHWJH  Export.table  daily_ndvi_by_soum_2008                     CANCELLED  Cancelled.
# 6XM73QN3EJT7AROJ5KM3AOOY  Export.table  daily_ndvi_by_soum_2007                     CANCELLED  Cancelled.
# Q23GQGZXHQ7O66HPKPZW5Z4M  Export.table  daily_ndvi_by_soum_2006                     CANCELLED  Cancelled.
# GYOTY6XV7IE3WMNNTXW7U2R4  Export.table  daily_ndvi_by_soum_2005                     CANCELLED  Cancelled.
# NFDZ64TKLWZFFI6RX6BILV5O  Export.table  daily_ndvi_by_soum_2004                     CANCELLED  Cancelled.
# JQHZAUFREMRQFZJPB4M3PFC7  Export.table  daily_ndvi_by_soum_2003                     CANCELLED  Cancelled.
# XVM4ZT3NLTNDP6DHKSLIMFMC  Export.table  daily_ndvi_by_soum_2002                     CANCELLED  Cancelled.
# ZW4JIPNOVJ52GFCUQQFAY4AY  Export.table  daily_ndvi_by_soum_2001                     CANCELLED  Cancelled.
# VRR5GYQZJNIMYXEFNMBFEQ3T  Export.table  daily_ndvi_by_soum_2000                     CANCELLED  Cancelled.
# W2NZGCKUQ6RYSEEJEKMQNYVO  Export.table  daily_ndvi_by_soum_1999                     CANCELLED  Cancelled.
# CCMAZ6NYC76OJLJFSQ4DB5GO  Export.table  daily_ndvi_by_soum_1998                     CANCELLED  Cancelled.
# C2RR6WW4A7EICKARVCAHQA7A  Export.table  daily_ndvi_by_soum_1997                     CANCELLED  Cancelled.
# BCLUU7UWN23LLJWE4XKMDRL7  Export.table  daily_ndvi_by_soum_1996                     CANCELLED  Cancelled.
# XG5KKNGNWJFYA2CNLUDQRUBP  Export.table  daily_ndvi_by_soum_1995                     CANCELLED  Cancelled.
# GZMP64WQSQUCHQBPH7U3I3N5  Export.table  daily_ndvi_by_soum_1994                     CANCELLED  Cancelled.
# F3V5WVJCA65PIJQXTG7NL3HU  Export.table  daily_ndvi_by_soum_1993                     CANCELLED  Cancelled.
# KDF5YB5ZJAGD3FPNQHEUSKFM  Export.table  daily_ndvi_by_soum_1992                     CANCELLED  Cancelled.
# ANIRYP4I2DPBLGQ6VVVZ3KAK  Export.table  daily_ndvi_by_soum_1991                     CANCELLED  Cancelled.
# L3KXC2KZYW644INECCGXVYBG  Export.table  daily_ndvi_by_soum_1990                     COMPLETED  ---
# 3MUDXSETY7XF4MVMEGTBJADT  Export.table  daily_ndvi_by_soum_1989                     COMPLETED  ---
# SZVHG7Y5HGKPM3FA6QC4QVVT  Export.table  daily_ndvi_by_soum_1988                     COMPLETED  ---
# 57ZICZ4OPWPKISZKNFMPUNVY  Export.table  daily_ndvi_by_soum_1987                     COMPLETED  ---
# DIFXYCI2MRW63TBCDJ7SI6VZ  Export.table  daily_ndvi_by_soum_1986                     COMPLETED  ---
# 5SVD47GSHFIQYQLA4VJQQBNT  Export.table  daily_ndvi_by_soum_1985                     COMPLETED  ---
# VB2LG4G5V2KDOARS7SWEO7IW  Export.table  daily_ndvi_by_soum_1985                     CANCELLED  Cancelled.
# AXD432IEC765HPH3OU2ACYM7  Export.table  daily_ndvi_by_soum_1985                     COMPLETED  ---
# LZSGEI7JLTTUFVXXWQ3EPLCU  Export.table  daily_ndvi_by_soum_1985                     COMPLETED  ---
# 4P7DADPWRFOCVFIIZ4NNTMFY  Export.table  daily_ndvi_by_soum_2020                     CANCELLED  Cancelled.
# JG5EEOOMDJA2IT6G6VDU7TOS  Export.table  daily_ndvi_by_soum_2019                     CANCELLED  Cancelled.
# HLEBDY55JEHL3LUGTVTZYLL7  Export.table  daily_ndvi_by_soum_2018                     CANCELLED  Cancelled.
# 3C2JYWQEOTPPD7BS2ZBO3DNL  Export.table  daily_ndvi_by_soum_2017                     CANCELLED  Cancelled.
# F5QBEVZVVIEDURE6O7UM2DMT  Export.table  daily_ndvi_by_soum_2016                     CANCELLED  Cancelled.
# O5OW3V3RDH5FOQBRTYWOGSMJ  Export.table  daily_ndvi_by_soum_2015                     CANCELLED  Cancelled.
# XTBDJIENUCPBIUY5APUOG4GY  Export.table  daily_ndvi_by_soum_2014                     CANCELLED  Cancelled.
# 4W2YVR4L7G4GU5MXNEQFHU6H  Export.table  daily_ndvi_by_soum_2013                     CANCELLED  Cancelled.
# W22MKEIF2B2EFM2V22FAYX2V  Export.table  daily_ndvi_by_soum_2012                     CANCELLED  Cancelled.
# X7YXHDME3FAMTIV4ABT7TGHI  Export.table  daily_ndvi_by_soum_2011                     CANCELLED  Cancelled.
# QZZ5APWWQUXVKHBQI5PYQ2L2  Export.table  daily_ndvi_by_soum_2010                     CANCELLED  Cancelled.
# OYVAZA5VMAAM65A5VEWWRXLX  Export.table  daily_ndvi_by_soum_2009                     CANCELLED  Cancelled.
# ZBSSV5HEJMWOKGVMW2KD2VQB  Export.table  daily_ndvi_by_soum_2008                     CANCELLED  Cancelled.
# LZBL7JM7ENO4BP7FUTMVNC7T  Export.table  daily_ndvi_by_soum_2007                     CANCELLED  Cancelled.
# MJTDUJ2HTTXCWQ6RX7PUZBIK  Export.table  daily_ndvi_by_soum_2006                     CANCELLED  Cancelled.
# 3IUCESMOPPY3U6GRDYLZFDQH  Export.table  daily_ndvi_by_soum_2005                     CANCELLED  Cancelled.
# 44SR2GFCZQYQWWAGWECO6XZU  Export.table  daily_ndvi_by_soum_2004                     CANCELLED  Cancelled.
# P4XIO6IWGCXO3R4KT7DCBSBU  Export.table  daily_ndvi_by_soum_2003                     CANCELLED  Cancelled.
# RWKYKIIZ6M5NVAYXYDLROCSO  Export.table  daily_ndvi_by_soum_2002                     CANCELLED  Cancelled.
# 4VWUGB3V4YJGRZHPXSHVKYCO  Export.table  daily_ndvi_by_soum_2001                     CANCELLED  Cancelled.
# LX3S6ZZ2NEOZDB4QPAZHEBOQ  Export.table  daily_ndvi_by_soum_2000                     CANCELLED  Cancelled.
# TZGZJTWZLVQVJGTMM2QZDSBU  Export.table  daily_ndvi_by_soum_1999                     CANCELLED  Cancelled.
# 2BM4EY3SEQFFGJ7LP7E2FP5S  Export.table  daily_ndvi_by_soum_1998                     COMPLETED  ---
# CDXMCVP5XPSWGSPZZST2F5M6  Export.table  daily_ndvi_by_soum_1997                     COMPLETED  ---
# R66ZMAKX4RDKDXEIYH5Z32IU  Export.table  daily_ndvi_by_soum_1996                     COMPLETED  ---
# B6NO5THMOGZAH32S4J4HSTQQ  Export.table  daily_ndvi_by_soum_1995                     COMPLETED  ---
# N6ORFDSH46XXWGQW64SCXJFF  Export.table  daily_ndvi_by_soum_1994                     COMPLETED  ---
# PO5HZXDVSAZJZZI4QR4P5FON  Export.table  daily_ndvi_by_soum_1993                     COMPLETED  ---
# RZCBPYJOCEZA6JLK2PREVP5N  Export.table  daily_ndvi_by_soum_1992                     COMPLETED  ---
# KJ2EDUYC2JUI3FBC54LIWGVI  Export.table  daily_ndvi_by_soum_1991                     COMPLETED  ---
# YN75YCBR3LSE46QD3FFFSMLD  Export.table  daily_ndvi_by_soum_1990                     COMPLETED  ---
# WNNN7WLZTRCXE4MCI2ZZTJWK  Export.table  daily_ndvi_by_soum_1989                     COMPLETED  ---
# SUBZVNZH3EU573YEL2VJDWYB  Export.table  daily_ndvi_by_soum_1988                     COMPLETED  ---
# ZUI2OITHPCXK46V2WVDNAQY6  Export.table  daily_ndvi_by_soum_1987                     COMPLETED  ---
# 4UZCFW3J6XJVLSNKFBAKY726  Export.table  daily_ndvi_by_soum_1986                     COMPLETED  ---
# Y3U3DNVVMTEICVQA3ZK63I3D  Export.table  daily_ndvi_by_soum_1985                     COMPLETED  ---
# SWIPWETBBI7TQXERB5JHAAW4  Export.table  daily_ndvi_by_soum_2019                     CANCELLED  Cancelled.
# PGPHSIDSKTUWT5PZLA4FD7JB  Export.table  daily_ndvi_by_soum_2018                     CANCELLED  Cancelled.
# 5YCSJETSWDCIG6RELV4ILZRH  Export.table  daily_ndvi_by_soum_2017                     CANCELLED  Cancelled.
# NMI6NWUJCDDSMNXKOBQKAF3K  Export.table  daily_ndvi_by_soum_2016                     CANCELLED  Cancelled.
# HZ7LNREFX5B4HVNRSKATIBTC  Export.table  daily_ndvi_by_soum_2015                     CANCELLED  Cancelled.
# H25M2NWRXQPBIYKMVS6CPIWP  Export.table  daily_ndvi_by_soum_2014                     CANCELLED  Cancelled.
# SE4QTDLB3CIYD3UMWBAUY43O  Export.table  daily_ndvi_by_soum_2013                     CANCELLED  Cancelled.
# 7NN66J44CFEBQYDEFAIIZLCI  Export.table  daily_ndvi_by_soum_2012                     CANCELLED  Cancelled.
# MGO5TZXIO5HGFGEPEQVQNNTQ  Export.table  daily_ndvi_by_soum_2011                     CANCELLED  Cancelled.
# PEM3T223YGONC5PICZEU4LGL  Export.table  daily_ndvi_by_soum_2010                     CANCELLED  Cancelled.
# QDL5TQHAMWWXTB2GTSWWMKRG  Export.table  daily_ndvi_by_soum_2009                     CANCELLED  Cancelled.
# 6H4DCZ2K3ZPGCTNKKJWFQQSU  Export.table  daily_ndvi_by_soum_2008                     CANCELLED  Cancelled.
# EB6LT7FMRPRL2QROH6BJQQR3  Export.table  daily_ndvi_by_soum_2007                     CANCELLED  Cancelled.
# R7NRL6H36XDRLY2F7Z3D3SN2  Export.table  daily_ndvi_by_soum_2006                     CANCELLED  Cancelled.
# NOFDJIZCDYPX4TPC7W7ZSMQ5  Export.table  daily_ndvi_by_soum_2005                     CANCELLED  Cancelled.
# YQW4VXKCLQVL2FPIFF3R7S2Q  Export.table  daily_ndvi_by_soum_2004                     CANCELLED  Cancelled.
# AKQALWN35EQY4RO2CFGKIPSD  Export.table  daily_ndvi_by_soum_2003                     CANCELLED  Cancelled.
# SNAXHUS7NJKNH2FB2P65IYJI  Export.table  daily_ndvi_by_soum_2002                     CANCELLED  Cancelled.
# RTZ7SXE7M5UH6LWZBB3MQZZL  Export.table  daily_ndvi_by_soum_2001                     CANCELLED  Cancelled.
# G7ZHQSOFHS5Z64LXA35EP354  Export.table  daily_ndvi_by_soum_2000                     CANCELLED  Cancelled.
# WF6GYXENSOQ63BYOQQA3LY5S  Export.table  daily_ndvi_by_soum_1999                     CANCELLED  Cancelled.
# 5U727WHS5DSPVEA7JDMVTQ7S  Export.table  daily_ndvi_by_soum_1998                     CANCELLED  Cancelled.
# TY22IQWPSOGB7QSKXX6BVJFR  Export.table  daily_ndvi_by_soum_1997                     CANCELLED  Cancelled.
# KGJZHAT3FNMSTMJIPHRQ5YSQ  Export.table  daily_ndvi_by_soum_1996                     CANCELLED  Cancelled.
# 7PYX3RPXLUXDQLHHRJNXCDLQ  Export.table  daily_ndvi_by_soum_1995                     CANCELLED  Cancelled.
# E6XX34LXUYAH3OLAMH2BCUU2  Export.table  daily_ndvi_by_soum_1994                     CANCELLED  Cancelled.
# S7TWBHDSF7XLFOVWEG5ITPAO  Export.table  daily_ndvi_by_soum_1993                     CANCELLED  Cancelled.
# 4OPREGT4QKEZPUTI6DKJTMDJ  Export.table  daily_ndvi_by_soum_1992                     CANCELLED  Cancelled.
# 6DGBNIU6SBQKDCTV6LPQPYP4  Export.table  daily_ndvi_by_soum_1991                     CANCELLED  Cancelled.
# URNJ6QWTRX7DD27G65QTZSYV  Export.table  daily_ndvi_by_soum_1990                     CANCELLED  Cancelled.
# 6PA5LETCMN2WV2N7NNH3UHJM  Export.table  daily_ndvi_by_soum_1989                     CANCELLED  Cancelled.
# 3IES6OTOGGBIHTHPOFGD3XEU  Export.table  daily_ndvi_by_soum_1988                     CANCELLED  Cancelled.
# U4MLMRZY27IWXFRMR6IOC7KV  Export.table  daily_ndvi_by_soum_1987                     CANCELLED  Cancelled.
# TCF5QLGNROJIY2TMNPH4HUZ3  Export.table  daily_ndvi_by_soum_1986                     CANCELLED  Cancelled.
# IHGPV4RNQB4VMHI54LIZDWA5  Export.table  daily_ndvi_by_soum_1985                     CANCELLED  Cancelled.
# DE4JRMGHLP2DGLVAJYYNJLWG  Export.table  daily_ndvi_by_soum_attempt0                 FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# RD2WLRXYYJYZPJKS72IIPN5S  Export.table  mock_export                                 COMPLETED  ---
# SNVIDHACSEELS2HADYBZX6MU  Export.table  monthly_ndvi_longformat_attempt1            FAILED     Image.date: Image 'LC08_122027_20130606' does not have a 'system:time_start' property.
# XEYK2O2MFTC6MA2WHS4IW7WR  Upload        Ingest image: "projects/earthengine-lega..  FAILED     Input file n45_45_2000lc030.tif, compared to the previously seen input files, has non-integer X offset 655.3638527409134. Error exceeds 0.01. Its affine vs current affine: AffineTransform[[30.0, 0.0, 262949.4115822272], [0.0, -30.0, 5543556.819406534]] vs AffineTransform[[30.0, 0.0, 243288.4959999998], [0.0, -30.0, 4987933.41]].
# UNHY2T66JJD3QDJ4LJWREEKE  Upload        Ingest image: "projects/earthengine-lega..  FAILED     Cannot overwrite asset 'projects/earthengine-legacy/assets/users/ta346/2000lc30'.
# XPD3L2PZIYNHATJHVQ2HOWI4  Export.table  monthly_ndvi_longformat_attempt0            CANCELLED  Cancelled.
# XK74OKU3RBETFGCHIWTFAMU2  Export.table  monthly_ndvi_longformat_attempt1            FAILED     Image.date: Image '1_LC08_122027_20130505' does not have a 'system:time_start' property.
# DABFCL4PJEUEX6F6EA35BIYH  Export.table  monthly_ndvi_longformat_attempt0            CANCELLED  Cancelled.
# 3VFFCPDVFJQR66HHYDYMY5GQ  Upload        Ingest image: "projects/earthengine-lega..  COMPLETED  ---
# XV7G6X4YR63SWXSIGS6BXX7N  Upload        Ingest image: "projects/earthengine-lega..  FAILED     Input file n45_45_2020lc030.tif, compared to the previously seen input files, has non-integer X offset 654.5916291107704. Error exceeds 0.01. Its affine vs current affine: AffineTransform[[30.0, 0.0, 256011.60131278043], [0.0, -30.0, 5550478.731203143]] vs AffineTransform[[30.0, 0.0, 236373.8524394573], [0.0, -30.0, 4994857.002444191]].
# 5I6B3ZQDITRH4OJ57ZJBF22R  Export.table  daily_ndvi_by_soum_2000                     FAILED     ImageCollection.mosaic: Error in map(ID=LE07_122027_20000525):
# Image.select: Pattern 'ndvi' did not match any bands.
# EWNR2RAB7RGH6RE3EIG5PTX5  Export.table  daily_ndvi_by_soum_2000                     FAILED     ImageCollection.mosaic: Error in map(ID=LE07_122027_20000509):
# Image.select: Pattern 'ndvi' did not match any bands.
# VDZYHARSQQH5GUCQSWNY52ZO  Export.table  daily_ndvi_by_soum_2000                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# LZKXE4GR53LIRUH3MESQAQPB  Export.table  daily_ndvi_by_soum_2000                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float.
#      Image ID: null
# This band might require an explicit cast.
# BXQY7YOLOQ7MSPTCXCFKMS7J  Export.table  daily_ndvi_by_soum_2000                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float.
#      Image ID: null
# This band might require an explicit cast.
# OWMR66XFSU7LJAWJZKEUGDYX  Export.table  daily_ndvi_by_soum_2000                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float.
#      Image ID: null
# This band might require an explicit cast.
# FBGC5T4U65XAOMCDRRCOI7UP  Export.table  daily_ndvi_by_soum_2000                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# DYCI3PX6II6V3I6LBVIBFPSS  Export.table  daily_ndvi_by_soum_2000                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# DMLZZGQ2ZUWMKVZXLVXSMHQO  Export.table  daily_ndvi_by_soum_2000                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# 2XF575VC5EUZFCWZ6E6LQYM2  Export.table  daily_ndvi_by_soum_2014                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-0.9589, 0.9589>.
#   Actual type: Float<-1.0, 1.0>.
#      Image ID: LE07_131031_20140531
# This band might require an explicit cast.
# I6F7WDJJTHW3DC6CJSZKCI2H  Export.table  daily_ndvi_by_soum_2020                     CANCELLED  Cancelled.
# VMZ3COONST2JPMVWZAA7KZW3  Export.table  daily_ndvi_by_soum_2020                     CANCELLED  Cancelled.
# EIUZ3OJQSJCVY6QS4O3XCCEC  Export.table  daily_ndvi_by_soum_2020                     CANCELLED  Cancelled.
# UH6JIO4RBBODJHGINBOMIZQF  Export.table  daily_ndvi_by_soum_2020                     CANCELLED  Cancelled.
# 47ZPBRNFFN57NVJRAX33EPLP  Export.table  daily_ndvi_by_soum_2019                     CANCELLED  Cancelled.
# W47GU5HRSLIV2ZH3UC2Z73B7  Export.table  daily_ndvi_by_soum_2018                     CANCELLED  Cancelled.
# QFNSROLJBY2C4OUDC4Y4JP2Z  Export.table  daily_ndvi_by_soum_2017                     CANCELLED  Cancelled.
# RZBWUOY5CVVEHS4P6WI5UIKB  Export.table  daily_ndvi_by_soum_2016                     CANCELLED  Cancelled.
# RH5E53KKQBXATS2UKUB6PBB3  Export.table  daily_ndvi_by_soum_2015                     CANCELLED  Cancelled.
# WSNWMAL5KDW6IV2VBPJSDGOW  Export.table  daily_ndvi_by_soum_2014                     CANCELLED  Cancelled.
# 5AOVKLPR5KYJEIU6QQNQNBH4  Export.table  daily_ndvi_by_soum_2013                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-0.9589, 0.9589>.
#   Actual type: Float<-1.0, 1.0>.
#      Image ID: LE07_123027_20130504
# This band might require an explicit cast.
# 3LFEHMBASK7OKT5XC5NBFSOX  Export.table  daily_ndvi_by_soum_2012                     CANCELLED  Cancelled.
# 3A26ZK6S4II7PZLRQR5CLUQN  Export.table  daily_ndvi_by_soum_2011                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# 4VRWB7C7TV7I77ZG5OZLYMAM  Export.table  daily_ndvi_by_soum_2010                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# R2LZDJE34KOALJ624WGIBONA  Export.table  daily_ndvi_by_soum_2009                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# I5IOR3BLCWTVLIO4F6WCL6FP  Export.table  daily_ndvi_by_soum_2008                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# XQ2MZPVZDXHWP6ORHJGO4HY2  Export.table  daily_ndvi_by_soum_2007                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# BDJWO6K6LGB7XBRS5ESQVUYL  Export.table  daily_ndvi_by_soum_2006                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# BKVQK6Z5UOK756QKK2HRAT7R  Export.table  daily_ndvi_by_soum_2005                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# QWZBXN5C3FB7PQBFNWD7XKXD  Export.table  daily_ndvi_by_soum_2004                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# IRT27FY27NYTLL2H7NSKWBFA  Export.table  daily_ndvi_by_soum_2003                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# ZUEB2GRV57MQYQ5I6FS3XGAZ  Export.table  daily_ndvi_by_soum_2002                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# YHQ2BLQSZTO2ZFUQUTZWROFE  Export.table  daily_ndvi_by_soum_2001                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# H5IKRIV3ZPHK6OG34FMS62UB  Export.table  daily_ndvi_by_soum_2000                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# 64VVDBYEAS3GCF3PFQDXSGAC  Export.table  daily_ndvi_by_soum_1999                     FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# T36QRKKBCLJTMQ3AS24XEX62  Export.table  daily_ndvi_by_soum_1998                     COMPLETED  ---
# FWIL5ANEXRXI4JQXCAH76NAH  Export.table  daily_ndvi_by_soum_1997                     COMPLETED  ---
# D3CQHOBBC2RWAZOOALNFWVDF  Export.table  daily_ndvi_by_soum_1996                     COMPLETED  ---
# H5FLY4JWZCQ4TEELQQNSJZOM  Export.table  daily_ndvi_by_soum_1995                     COMPLETED  ---
# JUPFD6EJDPINXBG7TUTHS2H6  Export.table  daily_ndvi_by_soum_1994                     COMPLETED  ---
# SRLZVLBRYRD7OVMNVBP6ER7E  Export.table  daily_ndvi_by_soum_1993                     COMPLETED  ---
# N3URBPDMQ46QKXZLRX3FLRQL  Export.table  daily_ndvi_by_soum_1992                     COMPLETED  ---
# J7MPVFXQKV4AYI3OSYUYXC6G  Export.table  daily_ndvi_by_soum_1991                     COMPLETED  ---
# 2JUB22FDRNKUIYMAAZVDJIFU  Export.table  daily_ndvi_by_soum_1990                     COMPLETED  ---
# GAPCAKMQNWLSBXXF34NM46B5  Export.table  daily_ndvi_by_soum_1989                     COMPLETED  ---
# 2WXSRHR3XTREK5NV4TKOGZ7M  Export.table  daily_ndvi_by_soum_1988                     COMPLETED  ---
# UPZZ6EQK2Q2GETO5QUD7IBI3  Export.table  daily_ndvi_by_soum_1987                     COMPLETED  ---
# J73LX75Y4UXVNHMVDXSXGGNP  Export.table  daily_ndvi_by_soum_1986                     COMPLETED  ---
# 6DPMMUFJ7JJNAESZZWLI6GCA  Export.table  daily_ndvi_by_soum_1985                     COMPLETED  ---
# 6MSVO3WHB6YMPJO3W6F7HDZA  Export.table  daily_ndvi_by_soum_1985                     CANCELLED  Cancelled.
# MU7I4RZ3D4HDPUPTUIC4YV2M  Export.table  daily_ndvi_by_soum_1985                     CANCELLED  Cancelled.
# RYVXX7MVAC45UZJ7ABXYDIXK  Export.table  daily_ndvi_by_soum_2020                     CANCELLED  Cancelled.
# QW5MKFAAYEIILB2DJJHRJHAO  Export.table  daily_ndvi_by_soum_2019                     CANCELLED  Cancelled.
# X6UE2VGQYRCYESHY7PHNIIML  Export.table  daily_ndvi_by_soum_2018                     CANCELLED  Cancelled.
# WFXBKF2YN3CBZD4V3T4FMETV  Export.table  daily_ndvi_by_soum_2017                     CANCELLED  Cancelled.
# 6KQSM273Q3QTTYEEUHEIZQIM  Export.table  daily_ndvi_by_soum_2016                     CANCELLED  Cancelled.
# GL7HKITRM2G2HYXVAP6MYHEK  Export.table  daily_ndvi_by_soum_2015                     CANCELLED  Cancelled.
# AZBOMXKKGR27JVVQWPU6MXQC  Export.table  daily_ndvi_by_soum_2014                     CANCELLED  Cancelled.
# RRSHR6WEYTNNOXUA5F3GEEOJ  Export.table  daily_ndvi_by_soum_2013                     CANCELLED  Cancelled.
# ZSEXSFHSDCMF3OHK4KGDTMC3  Export.table  daily_ndvi_by_soum_2012                     CANCELLED  Cancelled.
# PYNE62OIODYJE5KUMSEBYU7R  Export.table  daily_ndvi_by_soum_2011                     CANCELLED  Cancelled.
# ASNISL23TG3R5XG57V2SWYC3  Export.table  daily_ndvi_by_soum_2010                     CANCELLED  Cancelled.
# O5U7WDT5HDVL6SGGTMRQV2IH  Export.table  daily_ndvi_by_soum_2009                     CANCELLED  Cancelled.
# IO7IVUMUJNFV5JOIQ5UJHWJH  Export.table  daily_ndvi_by_soum_2008                     CANCELLED  Cancelled.
# 6XM73QN3EJT7AROJ5KM3AOOY  Export.table  daily_ndvi_by_soum_2007                     CANCELLED  Cancelled.
# Q23GQGZXHQ7O66HPKPZW5Z4M  Export.table  daily_ndvi_by_soum_2006                     CANCELLED  Cancelled.
# GYOTY6XV7IE3WMNNTXW7U2R4  Export.table  daily_ndvi_by_soum_2005                     CANCELLED  Cancelled.
# NFDZ64TKLWZFFI6RX6BILV5O  Export.table  daily_ndvi_by_soum_2004                     CANCELLED  Cancelled.
# JQHZAUFREMRQFZJPB4M3PFC7  Export.table  daily_ndvi_by_soum_2003                     CANCELLED  Cancelled.
# XVM4ZT3NLTNDP6DHKSLIMFMC  Export.table  daily_ndvi_by_soum_2002                     CANCELLED  Cancelled.
# ZW4JIPNOVJ52GFCUQQFAY4AY  Export.table  daily_ndvi_by_soum_2001                     CANCELLED  Cancelled.
# VRR5GYQZJNIMYXEFNMBFEQ3T  Export.table  daily_ndvi_by_soum_2000                     CANCELLED  Cancelled.
# W2NZGCKUQ6RYSEEJEKMQNYVO  Export.table  daily_ndvi_by_soum_1999                     CANCELLED  Cancelled.
# CCMAZ6NYC76OJLJFSQ4DB5GO  Export.table  daily_ndvi_by_soum_1998                     CANCELLED  Cancelled.
# C2RR6WW4A7EICKARVCAHQA7A  Export.table  daily_ndvi_by_soum_1997                     CANCELLED  Cancelled.
# BCLUU7UWN23LLJWE4XKMDRL7  Export.table  daily_ndvi_by_soum_1996                     CANCELLED  Cancelled.
# XG5KKNGNWJFYA2CNLUDQRUBP  Export.table  daily_ndvi_by_soum_1995                     CANCELLED  Cancelled.
# GZMP64WQSQUCHQBPH7U3I3N5  Export.table  daily_ndvi_by_soum_1994                     CANCELLED  Cancelled.
# F3V5WVJCA65PIJQXTG7NL3HU  Export.table  daily_ndvi_by_soum_1993                     CANCELLED  Cancelled.
# KDF5YB5ZJAGD3FPNQHEUSKFM  Export.table  daily_ndvi_by_soum_1992                     CANCELLED  Cancelled.
# ANIRYP4I2DPBLGQ6VVVZ3KAK  Export.table  daily_ndvi_by_soum_1991                     CANCELLED  Cancelled.
# L3KXC2KZYW644INECCGXVYBG  Export.table  daily_ndvi_by_soum_1990                     COMPLETED  ---
# 3MUDXSETY7XF4MVMEGTBJADT  Export.table  daily_ndvi_by_soum_1989                     COMPLETED  ---
# SZVHG7Y5HGKPM3FA6QC4QVVT  Export.table  daily_ndvi_by_soum_1988                     COMPLETED  ---
# 57ZICZ4OPWPKISZKNFMPUNVY  Export.table  daily_ndvi_by_soum_1987                     COMPLETED  ---
# DIFXYCI2MRW63TBCDJ7SI6VZ  Export.table  daily_ndvi_by_soum_1986                     COMPLETED  ---
# 5SVD47GSHFIQYQLA4VJQQBNT  Export.table  daily_ndvi_by_soum_1985                     COMPLETED  ---
# VB2LG4G5V2KDOARS7SWEO7IW  Export.table  daily_ndvi_by_soum_1985                     CANCELLED  Cancelled.
# AXD432IEC765HPH3OU2ACYM7  Export.table  daily_ndvi_by_soum_1985                     COMPLETED  ---
# LZSGEI7JLTTUFVXXWQ3EPLCU  Export.table  daily_ndvi_by_soum_1985                     COMPLETED  ---
# 4P7DADPWRFOCVFIIZ4NNTMFY  Export.table  daily_ndvi_by_soum_2020                     CANCELLED  Cancelled.
# JG5EEOOMDJA2IT6G6VDU7TOS  Export.table  daily_ndvi_by_soum_2019                     CANCELLED  Cancelled.
# HLEBDY55JEHL3LUGTVTZYLL7  Export.table  daily_ndvi_by_soum_2018                     CANCELLED  Cancelled.
# 3C2JYWQEOTPPD7BS2ZBO3DNL  Export.table  daily_ndvi_by_soum_2017                     CANCELLED  Cancelled.
# F5QBEVZVVIEDURE6O7UM2DMT  Export.table  daily_ndvi_by_soum_2016                     CANCELLED  Cancelled.
# O5OW3V3RDH5FOQBRTYWOGSMJ  Export.table  daily_ndvi_by_soum_2015                     CANCELLED  Cancelled.
# XTBDJIENUCPBIUY5APUOG4GY  Export.table  daily_ndvi_by_soum_2014                     CANCELLED  Cancelled.
# 4W2YVR4L7G4GU5MXNEQFHU6H  Export.table  daily_ndvi_by_soum_2013                     CANCELLED  Cancelled.
# W22MKEIF2B2EFM2V22FAYX2V  Export.table  daily_ndvi_by_soum_2012                     CANCELLED  Cancelled.
# X7YXHDME3FAMTIV4ABT7TGHI  Export.table  daily_ndvi_by_soum_2011                     CANCELLED  Cancelled.
# QZZ5APWWQUXVKHBQI5PYQ2L2  Export.table  daily_ndvi_by_soum_2010                     CANCELLED  Cancelled.
# OYVAZA5VMAAM65A5VEWWRXLX  Export.table  daily_ndvi_by_soum_2009                     CANCELLED  Cancelled.
# ZBSSV5HEJMWOKGVMW2KD2VQB  Export.table  daily_ndvi_by_soum_2008                     CANCELLED  Cancelled.
# LZBL7JM7ENO4BP7FUTMVNC7T  Export.table  daily_ndvi_by_soum_2007                     CANCELLED  Cancelled.
# MJTDUJ2HTTXCWQ6RX7PUZBIK  Export.table  daily_ndvi_by_soum_2006                     CANCELLED  Cancelled.
# 3IUCESMOPPY3U6GRDYLZFDQH  Export.table  daily_ndvi_by_soum_2005                     CANCELLED  Cancelled.
# 44SR2GFCZQYQWWAGWECO6XZU  Export.table  daily_ndvi_by_soum_2004                     CANCELLED  Cancelled.
# P4XIO6IWGCXO3R4KT7DCBSBU  Export.table  daily_ndvi_by_soum_2003                     CANCELLED  Cancelled.
# RWKYKIIZ6M5NVAYXYDLROCSO  Export.table  daily_ndvi_by_soum_2002                     CANCELLED  Cancelled.
# 4VWUGB3V4YJGRZHPXSHVKYCO  Export.table  daily_ndvi_by_soum_2001                     CANCELLED  Cancelled.
# LX3S6ZZ2NEOZDB4QPAZHEBOQ  Export.table  daily_ndvi_by_soum_2000                     CANCELLED  Cancelled.
# TZGZJTWZLVQVJGTMM2QZDSBU  Export.table  daily_ndvi_by_soum_1999                     CANCELLED  Cancelled.
# 2BM4EY3SEQFFGJ7LP7E2FP5S  Export.table  daily_ndvi_by_soum_1998                     COMPLETED  ---
# CDXMCVP5XPSWGSPZZST2F5M6  Export.table  daily_ndvi_by_soum_1997                     COMPLETED  ---
# R66ZMAKX4RDKDXEIYH5Z32IU  Export.table  daily_ndvi_by_soum_1996                     COMPLETED  ---
# B6NO5THMOGZAH32S4J4HSTQQ  Export.table  daily_ndvi_by_soum_1995                     COMPLETED  ---
# N6ORFDSH46XXWGQW64SCXJFF  Export.table  daily_ndvi_by_soum_1994                     COMPLETED  ---
# PO5HZXDVSAZJZZI4QR4P5FON  Export.table  daily_ndvi_by_soum_1993                     COMPLETED  ---
# RZCBPYJOCEZA6JLK2PREVP5N  Export.table  daily_ndvi_by_soum_1992                     COMPLETED  ---
# KJ2EDUYC2JUI3FBC54LIWGVI  Export.table  daily_ndvi_by_soum_1991                     COMPLETED  ---
# YN75YCBR3LSE46QD3FFFSMLD  Export.table  daily_ndvi_by_soum_1990                     COMPLETED  ---
# WNNN7WLZTRCXE4MCI2ZZTJWK  Export.table  daily_ndvi_by_soum_1989                     COMPLETED  ---
# SUBZVNZH3EU573YEL2VJDWYB  Export.table  daily_ndvi_by_soum_1988                     COMPLETED  ---
# ZUI2OITHPCXK46V2WVDNAQY6  Export.table  daily_ndvi_by_soum_1987                     COMPLETED  ---
# 4UZCFW3J6XJVLSNKFBAKY726  Export.table  daily_ndvi_by_soum_1986                     COMPLETED  ---
# Y3U3DNVVMTEICVQA3ZK63I3D  Export.table  daily_ndvi_by_soum_1985                     COMPLETED  ---
# SWIPWETBBI7TQXERB5JHAAW4  Export.table  daily_ndvi_by_soum_2019                     CANCELLED  Cancelled.
# PGPHSIDSKTUWT5PZLA4FD7JB  Export.table  daily_ndvi_by_soum_2018                     CANCELLED  Cancelled.
# 5YCSJETSWDCIG6RELV4ILZRH  Export.table  daily_ndvi_by_soum_2017                     CANCELLED  Cancelled.
# NMI6NWUJCDDSMNXKOBQKAF3K  Export.table  daily_ndvi_by_soum_2016                     CANCELLED  Cancelled.
# HZ7LNREFX5B4HVNRSKATIBTC  Export.table  daily_ndvi_by_soum_2015                     CANCELLED  Cancelled.
# H25M2NWRXQPBIYKMVS6CPIWP  Export.table  daily_ndvi_by_soum_2014                     CANCELLED  Cancelled.
# SE4QTDLB3CIYD3UMWBAUY43O  Export.table  daily_ndvi_by_soum_2013                     CANCELLED  Cancelled.
# 7NN66J44CFEBQYDEFAIIZLCI  Export.table  daily_ndvi_by_soum_2012                     CANCELLED  Cancelled.
# MGO5TZXIO5HGFGEPEQVQNNTQ  Export.table  daily_ndvi_by_soum_2011                     CANCELLED  Cancelled.
# PEM3T223YGONC5PICZEU4LGL  Export.table  daily_ndvi_by_soum_2010                     CANCELLED  Cancelled.
# QDL5TQHAMWWXTB2GTSWWMKRG  Export.table  daily_ndvi_by_soum_2009                     CANCELLED  Cancelled.
# 6H4DCZ2K3ZPGCTNKKJWFQQSU  Export.table  daily_ndvi_by_soum_2008                     CANCELLED  Cancelled.
# EB6LT7FMRPRL2QROH6BJQQR3  Export.table  daily_ndvi_by_soum_2007                     CANCELLED  Cancelled.
# R7NRL6H36XDRLY2F7Z3D3SN2  Export.table  daily_ndvi_by_soum_2006                     CANCELLED  Cancelled.
# NOFDJIZCDYPX4TPC7W7ZSMQ5  Export.table  daily_ndvi_by_soum_2005                     CANCELLED  Cancelled.
# YQW4VXKCLQVL2FPIFF3R7S2Q  Export.table  daily_ndvi_by_soum_2004                     CANCELLED  Cancelled.
# AKQALWN35EQY4RO2CFGKIPSD  Export.table  daily_ndvi_by_soum_2003                     CANCELLED  Cancelled.
# SNAXHUS7NJKNH2FB2P65IYJI  Export.table  daily_ndvi_by_soum_2002                     CANCELLED  Cancelled.
# RTZ7SXE7M5UH6LWZBB3MQZZL  Export.table  daily_ndvi_by_soum_2001                     CANCELLED  Cancelled.
# G7ZHQSOFHS5Z64LXA35EP354  Export.table  daily_ndvi_by_soum_2000                     CANCELLED  Cancelled.
# WF6GYXENSOQ63BYOQQA3LY5S  Export.table  daily_ndvi_by_soum_1999                     CANCELLED  Cancelled.
# 5U727WHS5DSPVEA7JDMVTQ7S  Export.table  daily_ndvi_by_soum_1998                     CANCELLED  Cancelled.
# TY22IQWPSOGB7QSKXX6BVJFR  Export.table  daily_ndvi_by_soum_1997                     CANCELLED  Cancelled.
# KGJZHAT3FNMSTMJIPHRQ5YSQ  Export.table  daily_ndvi_by_soum_1996                     CANCELLED  Cancelled.
# 7PYX3RPXLUXDQLHHRJNXCDLQ  Export.table  daily_ndvi_by_soum_1995                     CANCELLED  Cancelled.
# E6XX34LXUYAH3OLAMH2BCUU2  Export.table  daily_ndvi_by_soum_1994                     CANCELLED  Cancelled.
# S7TWBHDSF7XLFOVWEG5ITPAO  Export.table  daily_ndvi_by_soum_1993                     CANCELLED  Cancelled.
# 4OPREGT4QKEZPUTI6DKJTMDJ  Export.table  daily_ndvi_by_soum_1992                     CANCELLED  Cancelled.
# 6DGBNIU6SBQKDCTV6LPQPYP4  Export.table  daily_ndvi_by_soum_1991                     CANCELLED  Cancelled.
# URNJ6QWTRX7DD27G65QTZSYV  Export.table  daily_ndvi_by_soum_1990                     CANCELLED  Cancelled.
# 6PA5LETCMN2WV2N7NNH3UHJM  Export.table  daily_ndvi_by_soum_1989                     CANCELLED  Cancelled.
# 3IES6OTOGGBIHTHPOFGD3XEU  Export.table  daily_ndvi_by_soum_1988                     CANCELLED  Cancelled.
# U4MLMRZY27IWXFRMR6IOC7KV  Export.table  daily_ndvi_by_soum_1987                     CANCELLED  Cancelled.
# TCF5QLGNROJIY2TMNPH4HUZ3  Export.table  daily_ndvi_by_soum_1986                     CANCELLED  Cancelled.
# IHGPV4RNQB4VMHI54LIZDWA5  Export.table  daily_ndvi_by_soum_1985                     CANCELLED  Cancelled.
# DE4JRMGHLP2DGLVAJYYNJLWG  Export.table  daily_ndvi_by_soum_attempt0                 FAILED     Expected a homogeneous image collection, but an image with an incompatible band was encountered. Mismatched type for band 'ndvi':
# Expected type: Float<-1.0, 1.0>.
#   Actual type: Float<-1.037, 1.037>.
#      Image ID: null
# This band might require an explicit cast.
# RD2WLRXYYJYZPJKS72IIPN5S  Export.table  mock_export                                 COMPLETED  ---
# SNVIDHACSEELS2HADYBZX6MU  Export.table  monthly_ndvi_longformat_attempt1            FAILED     Image.date: Image 'LC08_122027_20130606' does not have a 'system:time_start' property.
# XEYK2O2MFTC6MA2WHS4IW7WR  Upload        Ingest image: "projects/earthengine-lega..  FAILED     Input file n45_45_2000lc030.tif, compared to the previously seen input files, has non-integer X offset 655.3638527409134. Error exceeds 0.01. Its affine vs current affine: AffineTransform[[30.0, 0.0, 262949.4115822272], [0.0, -30.0, 5543556.819406534]] vs AffineTransform[[30.0, 0.0, 243288.4959999998], [0.0, -30.0, 4987933.41]].
# UNHY2T66JJD3QDJ4LJWREEKE  Upload        Ingest image: "projects/earthengine-lega..  FAILED     Cannot overwrite asset 'projects/earthengine-legacy/assets/users/ta346/2000lc30'.
# XPD3L2PZIYNHATJHVQ2HOWI4  Export.table  monthly_ndvi_longformat_attempt0            CANCELLED  Cancelled.
# XK74OKU3RBETFGCHIWTFAMU2  Export.table  monthly_ndvi_longformat_attempt1            FAILED     Image.date: Image '1_LC08_122027_20130505' does not have a 'system:time_start' property.
# DABFCL4PJEUEX6F6EA35BIYH  Export.table  monthly_ndvi_longformat_attempt0            CANCELLED  Cancelled.
# 3VFFCPDVFJQR66HHYDYMY5GQ  Upload        Ingest image: "projects/earthengine-lega..  COMPLETED  ---
# XV7G6X4YR63SWXSIGS6BXX7N  Upload        Ingest image: "projects/earthengine-lega..  FAILED     Input file n45_45_2020lc030.tif, compared to the previously seen input files, has non-integer X offset 654.5916291107704. Error exceeds 0.01. Its affine vs current affine: AffineTransform[[30.0, 0.0, 256011.60131278043], [0.0, -30.0, 5550478.731203143]] vs AffineTransform[[30.0, 0.0, 236373.8524394573], [0.0, -30.0, 4994857.002444191]].

# %%
# !earthengine task list
